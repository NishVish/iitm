# %%
import pandas as pd

df = pd.read_csv("data.csv")

# default column
df["mice"] = False

# %%
df
# Out:
#     Sanjay Sir Markings                 Category  \
# 0                   NaN                      NaN
# 1                   NaN                      NaN
# 2                     1                  Leisure
# 3                   NaN                      NaN
# 4                     1  Skal Association Member
# ..                  ...                      ...
# 464                   1           Sanjay sir Imp
# 465                   1           Sanjay sir Imp
# 466                   1           Sanjay sir Imp
# 467                   1           Sanjay sir Imp
# 468                   1           Sanjay sir Imp
#
#                           Contact Name Designation  \
# 0                       Mr. Swapan Sil    Partner
# 1                       Mr Srinjoy Sen     Founder
# 2                        Mr Raja Banik   Director
# 3       Mr. Aloke Mondal / Moli Mondal         M D
# 4    Mr. Sanjeev Mehra / Venessa Mehra   Directors
# ..                                 ...         ...
# 464            Mr. Mohammed Zakauddin    Director
# 465                     Mr. Akbar Amin   Director
# 466               Mr. Sanjeev Churiwal    Director
# 467                    Ms. Punam Arora    Director
# 468                 Mr. Pramod Lunawat    Director
#
#                               Name Of The Company  \
# 0                                23 DEGREES NORTH
# 1                       3S Travel Network Pvt Ltd
# 2                           AAKASH GANGA HOLIDAYS
# 3                                  AAKRIT TOURISM
# 4               AARYAN LEISURE & HOLIDAYS PVT LTD
# ..                                            ...
# 464  THE HOLIDAY HUB (A UNIT OF CHANDANI TRAVELS)
# 465                                   Travel Zone
# 466                NIMBUS TOURS & TRAVELS PVT LTD
# 467              South Wind Travel Agents Pvt Ltd
# 468                              Millennium Event
#
#                                              Address 1  \
# 0                            189 A, Santoshpur Avenue,
# 1                          16/1 Prince Anwar Shah Road
# 2    BD 119, SALT LAKE, SECTOR I, NEAR BD MARKET, K...
# 3             B/24, East Rajapur Santoshpur Kolkata 75
# 4    7/1C, Hazra Road, (Edcon Swastika Building), 1...
# ..                                                 ...
# 464                                1/1, Camac Street,
# 465                     PS Arcade, 11, Sudder Street,
# 466                                 8/1, Loudon Street
# 467                 35, Chittaranjan Ave, Ground Floor
# 468                    25/7, Rustomjee Street, Kolkata
#
#                               Address 2     City      Pincode        State  \
# 0         Behind Central Bank Of India,  Kolkata       700075  West Bengal
# 1                                   NaN  Kolkata  West Bengal       700033
# 2                                   NaN  Kolkata          NaN  West Bengal
# 3                                   NaN  Kolkata       700075          NaN
# 4                             Flat 1B,   Kolkata       700026  West Bengal
# ..                                  ...      ...          ...          ...
# 464  Shree Manjari Building, 1st Floor,  Kolkata       700016  West Bengal
# 465                       Ground Floor,  Kolkata          NaN          NaN
# 466                                 NaN  Kolkata       700017  West Bengal
# 467                                 NaN  Kolkata       700012  West Bengal
# 468                                 NaN  Kolkata       700019  West Bengal
#
#      ... Contact Person 2.1 Designation 2.1 Email 4.1 Mobile 4.1  \
# 0    ...                NaN             NaN       NaN        NaN
# 1    ...                NaN             NaN       NaN        NaN
# 2    ...                NaN             NaN       NaN        NaN
# 3    ...                NaN             NaN       NaN        NaN
# 4    ...   00 91 7044076004             NaN       NaN        NaN
# ..   ...                ...             ...       ...        ...
# 464  ...                NaN             NaN       NaN        NaN
# 465  ...                NaN             NaN       NaN        NaN
# 466  ...                NaN             NaN       NaN        NaN
# 467  ...                NaN             NaN       NaN        NaN
# 468  ...                NaN             NaN       NaN        NaN
#
#                 Email 1.1                       domain  \
# 0               info.23dn                    gmail.com
# 1                 srinjoy          3stravelnetwork.com
# 2    salesaakashganga1994                    gmail.com
# 3           aakrittourism                    gmail.com
# 4           sanjeev.mehra           aaryanholidays.com
# ..                    ...                          ...
# 464                  zaka                holidayhub.in
# 465                 akbar            travelzone360.com
# 466             shreyanka               nimbustours.in
# 467       punam_southwind                    yahoo.com
# 468                  info  millenniumevent.com, pramod
#
#                  Unnamed: 25          Unnamed: 26 Unnamed: 27   mice
# 0                        NaN                  NaN         NaN  False
# 1                        NaN                  NaN         NaN  False
# 2                        NaN                  NaN         NaN  False
# 3                        NaN                  NaN         NaN  False
# 4                        NaN                  NaN         NaN  False
# ..                       ...                  ...         ...    ...
# 464                      NaN                  NaN         NaN  False
# 465                      NaN                  NaN         NaN  False
# 466                      NaN                  NaN         NaN  False
# 467                      NaN                  NaN         NaN  False
# 468  marriageuana.com, rishi  millenniumevent.com         NaN  False
#
# [469 rows x 29 columns]

# %%
import pandas as pd
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

df = pd.read_csv("data.csv")
df["mice"] = False

HEADERS = {"User-Agent": "Mozilla/5.0"}

EMAIL_PROVIDERS = ["gmail.com", "yahoo.com", "ymail.com", "hotmail.com", "outlook.com"]


def is_email_provider(domain):
    if pd.isna(domain):
        return False
    domain = str(domain).lower()
    return any(p in domain for p in EMAIL_PROVIDERS)


# -----------------------------
# GET ALL INTERNAL LINKS
# -----------------------------
def get_internal_links(base_url, soup):
    links = set()

    for a in soup.find_all("a", href=True):
        href = a["href"]
        full_url = urljoin(base_url, href)

        # keep only same domain
        if urlparse(full_url).netloc == urlparse(base_url).netloc:
            links.add(full_url)

    return list(links)


# -----------------------------
# CHECK PAGE FOR MICE
# -----------------------------
def page_has_mice(url):
    try:
        r = requests.get(url, headers=HEADERS, timeout=8)
        if r.status_code != 200:
            return False

        soup = BeautifulSoup(r.text, "html.parser")
        text = soup.get_text(separator=" ").lower()

        return "mice" in text, soup

    except:
        return False, None


# -----------------------------
# CRAWLER (MULTI PAGE)
# -----------------------------
def crawl_domain_for_mice(domain):
    try:
        if not domain.startswith("http"):
            base_url = "https://" + domain
        else:
            base_url = domain

        print(f"    🌐 Opening: {base_url}")

        r = requests.get(base_url, headers=HEADERS, timeout=10)
        if r.status_code != 200:
            return False

        soup = BeautifulSoup(r.text, "html.parser")

        # check homepage
        text = soup.get_text(separator=" ").lower()
        if "mice" in text:
            return True

        # collect internal links
        links = get_internal_links(base_url, soup)
        links = links[:10]  # limit crawl

        print(f"    🔗 Found {len(links)} internal links")

        for idx, link in enumerate(links):
            print(f"      → Crawling [{idx+1}/{len(links)}]: {link}")

            has_mice, _ = page_has_mice(link)
            if has_mice:
                print("      ✅ MICE FOUND on page!")
                return True

        return False

    except Exception as e:
        print(f"    ❌ Error: {e}")
        return False


# -----------------------------
# SEARCH FOR EMAIL DOMAINS
# -----------------------------
def search_and_check_mice(query):
    try:
        url = "https://html.duckduckgo.com/html/?q=" + urllib.parse.quote(query)

        r = requests.get(url, headers=HEADERS, timeout=10)
        soup = BeautifulSoup(r.text, "html.parser")

        text = soup.get_text(separator=" ").lower()
        return "mice" in text

    except:
        return False


# -----------------------------
# MAIN LOOP
# -----------------------------
total = len(df)

for i, row in df.iterrows():
    company = row.get("Name Of The Company")
    domain = row.get("domain")

    print(f"\n[STEP {i+1}/{total}] {company}")

    found = False

    if is_email_provider(domain):
        print("  📧 Email domain → search mode")

        query = f"{company} MICE meetings incentives conferences exhibitions"
        print(f"  🔍 Query: {query}")

        found = search_and_check_mice(query)

    else:
        print("  🌍 Website domain → crawler mode")

        found = crawl_domain_for_mice(domain)

    df.at[i, "mice"] = found

    print(f"  ✔ RESULT: {found}")


df.to_csv("data_with_mice.csv", index=False)
print("\nDONE ✔ Saved file")
# Out:
# [STEP 1/469] 23 DEGREES NORTH
#   📧 Email domain → search mode
#   🔍 Query: 23 DEGREES NORTH MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 2/469] 3S Travel Network Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://3stravelnetwork.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://3stravelnetwork.com/tour/cambodia/
#       → Crawling [2/10]: https://3stravelnetwork.com/privacy-policy/
#       → Crawling [3/10]: https://3stravelnetwork.com/tour/vietnam/
#       → Crawling [4/10]: https://3stravelnetwork.com/tour/spain/
#       → Crawling [5/10]: https://3stravelnetwork.com/tour/turkey/
#       → Crawling [6/10]: https://3stravelnetwork.com/about/
#       → Crawling [7/10]: https://3stravelnetwork.com/tours/
#       → Crawling [8/10]: https://3stravelnetwork.com/tour/switzerland/
#       → Crawling [9/10]: https://3stravelnetwork.com/to_book/spain-portugal/
#       → Crawling [10/10]: https://3stravelnetwork.com/cancellation-refund-policy/
#   ✔ RESULT: False
#
# [STEP 3/469] AAKASH GANGA HOLIDAYS
#   📧 Email domain → search mode
#   🔍 Query: AAKASH GANGA HOLIDAYS MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 4/469] AAKRIT TOURISM
#   📧 Email domain → search mode
#   🔍 Query: AAKRIT TOURISM MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 5/469] AARYAN LEISURE & HOLIDAYS PVT LTD
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://aaryanholidays.com
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 6/469] ADH TOURS AND TRAVELS PVT. LTD.
#   📧 Email domain → search mode
#   🔍 Query: ADH TOURS AND TRAVELS PVT. LTD. MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 7/469] ADITI TOUR AND TRAVELS
#   📧 Email domain → search mode
#   🔍 Query: ADITI TOUR AND TRAVELS MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 8/469] ADORE VACATIONS
#   📧 Email domain → search mode
#   🔍 Query: ADORE VACATIONS MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 9/469] AGWANI TRAVELS PVT LTD.
#   📧 Email domain → search mode
#   🔍 Query: AGWANI TRAVELS PVT LTD. MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 10/469] AIR INFINITY TOURS & TRAVELS
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://airinfinitytravels.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://airinfinitytravels.com/#testimonials
#       → Crawling [2/10]: https://airinfinitytravels.com/#service-2
#       → Crawling [3/10]: https://airinfinitytravels.com/#why-us
#       → Crawling [4/10]: https://airinfinitytravels.com/#process
#       → Crawling [5/10]: https://airinfinitytravels.com/#reviews
#       → Crawling [6/10]: https://airinfinitytravels.com/#services
#       → Crawling [7/10]: https://airinfinitytravels.com/#service-4
#       → Crawling [8/10]: https://airinfinitytravels.com/#package-1
#       → Crawling [9/10]: https://airinfinitytravels.com/#contact
#       → Crawling [10/10]: https://airinfinitytravels.com/#travel-stories
#   ✔ RESULT: False
#
# [STEP 11/469] AIRCOM TRAVELS PVT LTD
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://aircomtravels.com
#   ✔ RESULT: False
#
# [STEP 12/469] AIRIXB
#   📧 Email domain → search mode
#   🔍 Query: AIRIXB MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 13/469] AKASH TOURISM
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://rediffmail.com
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 14/469] AKBAR TRAVELS OF INDIA PVT LTD
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://akbartravels.in
