# %%
import pandas as pd

df = pd.read_csv("data.csv")

# default column
df["mice"] = False

# %%
df
# Out:
#      Sanjay Sir Markings Sangeetha Comments                         Category  \
# 0                    NaN                NaN                              NaN
# 1                    NaN                NaN                              NaN
# 2                    NaN                NaN                              NaN
# 3                    NaN                NaN                              NaN
# 4                    NaN                NaN                              NaN
# ..                   ...                ...                              ...
# 672                  1.0                NaN        Gujarat Chapter- TAFI-Sec
# 673                  1.0                NaN  Gujarat Chapter- TAFI-Treasurer
# 674                  NaN                NaN            Gujarat Chapter- TAFI
# 675                  NaN                NaN            Gujarat Chapter- TAFI
# 676                  NaN                NaN            Gujarat Chapter- TAFI
#
#     Unnamed: 3              Name Of The Company  \
# 0          NaN            1497 Originals senses
# 1          Yes  360 Degree Travel Concierge LLP
# 2          NaN                7 Planet Holidays
# 3          NaN                 7 seas vacations
# 4          NaN                  99 Destinations
# ..         ...                              ...
# 672        NaN         Bleach Tourism Pvt. Ltd.
# 673        NaN                  Sanskar Travels
# 674        NaN        Zoom Travelling Pvt. Ltd.
# 675        NaN            Royal Tours & Travels
# 676        NaN    Stelle Tours & Forex Pvt. Ltd
#
#                          Contact Name                       Designation  \
# 0                   Mr Daxesh Badheka                        co-Founder
# 1    Ms Julie Lewis/Munifa Sareshwala                           Partner
# 2                   Mr Dhrupesh Patel                 Managing Director
# 3                        Mr R.B Patel                        Proprietor
# 4                          Ms Manisha                 Senior Operations
# ..                                ...                               ...
# 672                  Mr. Bijal J Shah                         Secretary
# 673            Mr. Rajneesh Bhatnagar                         Treasurer
# 674                Mr. Himanshu Patel                  Committee Member
# 675                Mr. Keyur Gondalia                  Committee Member
# 676                Mr. Kishan Sidpara  Conveyor - Rajkot City Committee
#
#                                              Address 1  \
# 0    A-209 Mondeal Heights Near Wide Angle, Next to...
# 1    Besides Binori Hotel, Binori Ambit, 203, Sarkh...
# 2       Ls no 122 Nr, shivalik villa, angan cross road
# 3                           401 Pushpam Mall, 100 Feet
# 4    Golden Arc, G2/G3, Atabhai Rd, Bhavnagar, Gujarat
# ..                                                 ...
# 672                                                NaN
# 673                                                NaN
# 674                                                NaN
# 675                                                NaN
# 676                                                NaN
#
#                        Address 2       City  ... Email 3 Mobile 3 Unnamed: 20  \
# 0                            NaN  Ahmedabad  ...     NaN      NaN         NaN
# 1                            NaN  Ahmedabad  ...     NaN      NaN         NaN
# 2    Rajpath rangoli road, ambli  Ahmedabad  ...     NaN      NaN         NaN
# 3                Anandnagar Road  Ahmedabad  ...     NaN      NaN         NaN
# 4                            NaN  Ahmedabad  ...     NaN      NaN         NaN
# ..                           ...        ...  ...     ...      ...         ...
# 672                          NaN        NaN  ...     NaN      NaN         NaN
# 673                          NaN        NaN  ...     NaN      NaN         NaN
# 674                          NaN        NaN  ...     NaN      NaN         NaN
# 675                          NaN        NaN  ...     NaN      NaN         NaN
# 676                          NaN        NaN  ...     NaN      NaN         NaN
#
#     Unnamed: 21            Email 1.1                domain domain2  \
# 0           NaN               daxesh            osenses.in     NaN
# 1           NaN              enquiry      360travelcon.com     NaN
# 2           NaN             dhrupesh   7planetholidays.com     NaN
# 3           NaN  7seasvacationsindia             gmail.com     NaN
# 4           NaN                trips     99destinations.in     NaN
# ..          ...                  ...                   ...     ...
# 672         NaN                bijal     bleachtourism.com     NaN
# 673         NaN        sanskartravel             ymail.com     NaN
# 674         NaN                  ops  zoomtravelling.co.in     NaN
# 675         NaN    royaltoursntravel             gmail.com     NaN
# 676         NaN               kishan       stelletours.com     NaN
#
#     Unnamed: 25 Unnamed: 26   mice
# 0           NaN         NaN  False
# 1           NaN         NaN  False
# 2           NaN         NaN  False
# 3           NaN         NaN  False
# 4           NaN         NaN  False
# ..          ...         ...    ...
# 672         NaN         NaN  False
# 673         NaN         NaN  False
# 674         NaN         NaN  False
# 675         NaN         NaN  False
# 676         NaN         NaN  False
#
# [677 rows x 28 columns]

# %%
import pandas as pd
import requests
import urllib.parse
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

df = pd.read_csv("data.csv")
df["mice"] = False

HEADERS = {"User-Agent": "Mozilla/5.0"}

EMAIL_PROVIDERS = ["gmail.com", "yahoo.com", "ymail.com", "hotmail.com", "outlook.com"]


def is_email_provider(domain):
    if pd.isna(domain):
        return False
    domain = str(domain).lower()
    return any(p in domain for p in EMAIL_PROVIDERS)


# -----------------------------
# GET ALL INTERNAL LINKS
# -----------------------------
def get_internal_links(base_url, soup):
    links = set()

    for a in soup.find_all("a", href=True):
        href = a["href"]
        full_url = urljoin(base_url, href)

        # keep only same domain
        if urlparse(full_url).netloc == urlparse(base_url).netloc:
            links.add(full_url)

    return list(links)


# -----------------------------
# CHECK PAGE FOR MICE
# -----------------------------
def page_has_mice(url):
    try:
        r = requests.get(url, headers=HEADERS, timeout=8)
        if r.status_code != 200:
            return False

        soup = BeautifulSoup(r.text, "html.parser")
        text = soup.get_text(separator=" ").lower()

        return "mice" in text, soup

    except:
        return False, None


# -----------------------------
# CRAWLER (MULTI PAGE)
# -----------------------------
def crawl_domain_for_mice(domain):
    try:
        if not domain.startswith("http"):
            base_url = "https://" + domain
        else:
            base_url = domain

        print(f"    🌐 Opening: {base_url}")

        r = requests.get(base_url, headers=HEADERS, timeout=10)
        if r.status_code != 200:
            return False

        soup = BeautifulSoup(r.text, "html.parser")

        # check homepage
        text = soup.get_text(separator=" ").lower()
        if "mice" in text:
            return True

        # collect internal links
        links = get_internal_links(base_url, soup)
        links = links[:10]  # limit crawl

        print(f"    🔗 Found {len(links)} internal links")

        for idx, link in enumerate(links):
            print(f"      → Crawling [{idx+1}/{len(links)}]: {link}")

            has_mice, _ = page_has_mice(link)
            if has_mice:
                print("      ✅ MICE FOUND on page!")
                return True

        return False

    except Exception as e:
        print(f"    ❌ Error: {e}")
        return False


# -----------------------------
# SEARCH FOR EMAIL DOMAINS
# -----------------------------
def search_and_check_mice(query):
    try:
        url = "https://html.duckduckgo.com/html/?q=" + urllib.parse.quote(query)

        r = requests.get(url, headers=HEADERS, timeout=10)
        soup = BeautifulSoup(r.text, "html.parser")

        text = soup.get_text(separator=" ").lower()
        return "mice" in text

    except:
        return False


# -----------------------------
# MAIN LOOP
# -----------------------------
total = len(df)

for i, row in df.iterrows():
    company = row.get("Name Of The Company")
    domain = row.get("domain")

    print(f"\n[STEP {i+1}/{total}] {company}")

    found = False

    if is_email_provider(domain):
        print("  📧 Email domain → search mode")

        query = f"{company} MICE meetings incentives conferences exhibitions"
        print(f"  🔍 Query: {query}")

        found = search_and_check_mice(query)

    else:
        print("  🌍 Website domain → crawler mode")

        found = crawl_domain_for_mice(domain)

    df.at[i, "mice"] = found

    print(f"  ✔ RESULT: {found}")


df.to_csv("data_with_mice.csv", index=False)
print("\nDONE ✔ Saved file")
# Out:
# [STEP 1/677] 1497 Originals senses
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://osenses.in
#   ✔ RESULT: False
#
# [STEP 2/677] 360 Degree Travel Concierge LLP
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://360travelcon.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://360travelcon.com/@360.html
#       → Crawling [2/10]: https://360travelcon.com/australia.html
#       → Crawling [3/10]: https://360travelcon.com/republic-of-singapore.html
#       → Crawling [4/10]: https://360travelcon.com/destinations.html
#       → Crawling [5/10]: https://360travelcon.com/north-america.html
#       → Crawling [6/10]: https://360travelcon.com/west-coast-usa.html
#       → Crawling [7/10]: https://360travelcon.com/corporate.html
#       ✅ MICE FOUND on page!
#   ✔ RESULT: True
#
# [STEP 3/677] 7 Planet Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://7planetholidays.com
#     🔗 Found 2 internal links
#       → Crawling [1/2]: https://7planetholidays.com#
#       → Crawling [2/2]: https://7planetholidays.com/
#   ✔ RESULT: False
#
# [STEP 4/677] 7 seas vacations
#   📧 Email domain → search mode
#   🔍 Query: 7 seas vacations MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 5/677] 99 Destinations
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://99destinations.in
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://99destinations.in/indian-holidays
#       → Crawling [2/10]: https://99destinations.in/pay-online-razorpay
#       → Crawling [3/10]: https://99destinations.in/
#       → Crawling [4/10]: https://99destinations.in/visa-service
#       → Crawling [5/10]: https://99destinations.in/international-tour-detail/greece/greece-special-7-days
#       → Crawling [6/10]: https://99destinations.in/indian-tour-detail/lakshadweep-tourism/cordelia-cruise-5-days
#       → Crawling [7/10]: https://99destinations.in/international-tour-detail/madagascar/classic-madagascar-7-days
#       → Crawling [8/10]: https://99destinations.in/indian-tour-detail/chhattisgarh-tourism/classic-chhattisgarh-5-days
#       → Crawling [9/10]: https://99destinations.in/indian-tour-detail/gujarat-tourism/gujarat-textile-tour-9-days
#       → Crawling [10/10]: https://99destinations.in/international-tour-detail/reunion-island/lagoon-dreams-7-days
#   ✔ RESULT: False
#
# [STEP 6/677] A & C Travels
#   📧 Email domain → search mode
#   🔍 Query: A & C Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 7/677] A Class Holidays
#   📧 Email domain → search mode
#   🔍 Query: A Class Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 8/677] A To Z Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://atozholidays.in
#   ✔ RESULT: False
#
# [STEP 9/677] A Too Z Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: A Too Z Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 10/677] A1 Tours
#   📧 Email domain → search mode
#   🔍 Query: A1 Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 11/677] A3 HOLIDAYS
#   📧 Email domain → search mode
#   🔍 Query: A3 HOLIDAYS MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 12/677] Aakash Tours
#   📧 Email domain → search mode
#   🔍 Query: Aakash Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 13/677] Aapka Holidays Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://aapkaholidays.in
#   ✔ RESULT: False
#
# [STEP 14/677] Aarav Trips
#   📧 Email domain → search mode
#   🔍 Query: Aarav Trips MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 15/677] Aarush Tours & Travel
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://aarushtours.com, aarushtours
#     ❌ Error: HTTPSConnectionPool(host='aarushtours.com,%20aarushtours', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='aarushtours.com,%20aarushtours', port=443): Failed to resolve 'aarushtours.com,%20aarushtours' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 16/677] Aarvi Holidays llp
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://aarviholiday.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://aarviholiday.com/tour-plans
#       → Crawling [2/10]: https://aarviholiday.com/contact
#       → Crawling [3/10]: https://aarviholiday.com/plan-details/17/singapore-malaysia-with-07-star-dream-cruise
#     ❌ Error: cannot unpack non-iterable bool object
#   ✔ RESULT: False
#
# [STEP 17/677] Aash Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Aash Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 18/677] Aashi Travels
#   📧 Email domain → search mode
#   🔍 Query: Aashi Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 19/677] Aastha Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://yahoo.co.in
#   ✔ RESULT: False
#
# [STEP 20/677] Aatithya Trips Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://aatithyaholidays.com, sales
#     ❌ Error: HTTPSConnectionPool(host='aatithyaholidays.com,%20sales', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='aatithyaholidays.com,%20sales', port=443): Failed to resolve 'aatithyaholidays.com,%20sales' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 21/677] Aayush Tours
#   📧 Email domain → search mode
#   🔍 Query: Aayush Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 22/677] Aboard Holidays
#   🌍 Website domain → crawler mode
#     ❌ Error: 'float' object has no attribute 'startswith'
#   ✔ RESULT: False
#
# [STEP 23/677] Accel Holidays Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://accelholidays.com
#   ✔ RESULT: False
#
# [STEP 24/677] Accord Travel
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://accordtravel.in
#     ❌ Error: HTTPSConnectionPool(host='accordtravel.in', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<HTTPSConnection(host='accordtravel.in', port=443) at 0x1deaae58410>, 'Connection to accordtravel.in timed out. (connect timeout=10)'))
#   ✔ RESULT: False
#
# [STEP 25/677] ACE Tours 'N' Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://yahoo.co.in , ace_visas
#     ❌ Error: HTTPSConnectionPool(host='yahoo.co.in%20,%20ace_visas', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='yahoo.co.in%20,%20ace_visas', port=443): Failed to resolve 'yahoo.co.in%20,%20ace_visas' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 26/677] Acorn Travels
#   📧 Email domain → search mode
#   🔍 Query: Acorn Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 27/677] Adiman's Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://adimanstravels.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://adimanstravels.com/thailand-tourism/
#       → Crawling [2/10]: https://adimanstravels.com/cruise/
#       → Crawling [3/10]: https://adimanstravels.com/faq/
#       → Crawling [4/10]: https://adimanstravels.com
#       → Crawling [5/10]: https://adimanstravels.com/international-tour/
#       → Crawling [6/10]: https://adimanstravels.com/paris-tourism/
#       → Crawling [7/10]: https://adimanstravels.com/honeymoon/
#       → Crawling [8/10]: https://adimanstravels.com/about-us/
#       → Crawling [9/10]: https://adimanstravels.com/singapore-tourism/
#       → Crawling [10/10]: https://adimanstravels.com/seychelles-tourism/
#   ✔ RESULT: False
#
# [STEP 28/677] Adstar Holidays
#   📧 Email domain → search mode
#   🔍 Query: Adstar Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 29/677] Advance Travels Pvt Ltd
#   📧 Email domain → search mode
#   🔍 Query: Advance Travels Pvt Ltd MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 30/677] Aireo Complete Travel Solution
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://aireo.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 31/677] Airways Worlds Travel
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://yahoo.co.in
#   ✔ RESULT: False
#
# [STEP 32/677] Airwings Holidays / Vacation Exotica
#   📧 Email domain → search mode
#   🔍 Query: Airwings Holidays / Vacation Exotica MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 33/677] Ajaramar world Travels
#   📧 Email domain → search mode
#   🔍 Query: Ajaramar world Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 34/677] Ajay Modi Travels Pvt Ltd
#   📧 Email domain → search mode
#   🔍 Query: Ajay Modi Travels Pvt Ltd MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 35/677] Akbar Travels Of India Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://akbarholidays.com ,sales.amd
#     ❌ Error: HTTPSConnectionPool(host='akbarholidays.com%20,sales.amd', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='akbarholidays.com%20,sales.amd', port=443): Failed to resolve 'akbarholidays.com%20,sales.amd' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 36/677] Akshar Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://aksharholidays.com
#     🔗 Found 2 internal links
#       → Crawling [1/2]: https://aksharholidays.com/about-us.htm
#       → Crawling [2/2]: https://aksharholidays.com#
#   ✔ RESULT: False
#
# [STEP 37/677] Akshar Travels Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://akshartours.com
#     ❌ Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#   ✔ RESULT: False
#
# [STEP 38/677] Akshar World Travels
#   📧 Email domain → search mode
#   🔍 Query: Akshar World Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 39/677] al hasan tours and travels
#   📧 Email domain → search mode
#   🔍 Query: al hasan tours and travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 40/677] Alankar Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Alankar Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 41/677] Alka Airlinks
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://alkatravel.com
#     ❌ Error: HTTPSConnectionPool(host='alkatravel.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='alkatravel.com', port=443): Failed to resolve 'alkatravel.com' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 42/677] All 4 Season Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://ALL4SEASON.COM,kavisha
#     ❌ Error: HTTPSConnectionPool(host='all4season.com,kavisha', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='all4season.com,kavisha', port=443): Failed to resolve 'all4season.com,kavisha' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 43/677] All Four
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://all4season.com
#   ✔ RESULT: True
#
# [STEP 44/677] Amar Bhoomika Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Amar Bhoomika Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 45/677] Amazing Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://amazingholiday.in, amazingholidays8081
#     ❌ Error: HTTPSConnectionPool(host='amazingholiday.in,%20amazingholidays8081', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='amazingholiday.in,%20amazingholidays8081', port=443): Failed to resolve 'amazingholiday.in,%20amazingholidays8081' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 46/677] Ambica Global Services
#   📧 Email domain → search mode
#   🔍 Query: Ambica Global Services MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 47/677] Ambition Holidays
#   📧 Email domain → search mode
#   🔍 Query: Ambition Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 48/677] Ami Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Ami Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 49/677] Amicale Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://amicaleholidays.com
#   ✔ RESULT: False
#
# [STEP 50/677] Amit Travels
#   📧 Email domain → search mode
#   🔍 Query: Amit Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 51/677] Amity Tours
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://amitytours.in
#   ✔ RESULT: False
#
# [STEP 52/677] Amity Tours & Travel
#   📧 Email domain → search mode
#   🔍 Query: Amity Tours & Travel MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 53/677] Anant Getaways
#   🌍 Website domain → crawler mode
#     ❌ Error: 'float' object has no attribute 'startswith'
#   ✔ RESULT: False
#
# [STEP 54/677] Ananta Tourism
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://anantatourism.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://anantatourism.com/tour-category/holiday-packages/
#       → Crawling [2/10]: https://anantatourism.com#
#       → Crawling [3/10]: https://anantatourism.com/about-us/
#       → Crawling [4/10]: https://anantatourism.com/our-serivces/air-ticket/
#       → Crawling [5/10]: https://anantatourism.com/tour-category/visa-service/
#       → Crawling [6/10]: https://anantatourism.com/our-serivces/holiday-packages-for-international-and-domestic/
#       → Crawling [7/10]: https://anantatourism.com/tour-category/hotel-booking/
#       → Crawling [8/10]: https://anantatourism.com/our-serivces/
#       → Crawling [9/10]: https://anantatourism.com/about-us/payment-details/
#       → Crawling [10/10]: https://anantatourism.com/our-serivces/visa-service/
#   ✔ RESULT: False
#
# [STEP 55/677] Andeverywhere Global
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://andeverywhere.co
#   ✔ RESULT: True
#
# [STEP 56/677] Aneri Holiday / Ruchal Holidays
#   📧 Email domain → search mode
#   🔍 Query: Aneri Holiday / Ruchal Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 57/677] Angel Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Angel Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 58/677] Apple Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Apple Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 59/677] Arham Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Arham Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 60/677] Arizona Holidays Pvt Ltd
#   📧 Email domain → search mode
#   🔍 Query: Arizona Holidays Pvt Ltd MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 61/677] Arya Tours
#   📧 Email domain → search mode
#   🔍 Query: Arya Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 62/677] ashapura tours and travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://ashapuratoursandtravel.com/ashapuratravels19
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://ashapuratoursandtravel.com/tos
#       → Crawling [2/10]: https://ashapuratoursandtravel.com/domain/bakkal.co
#       → Crawling [3/10]: https://ashapuratoursandtravel.com/domain/akwarium.com/backlink?hash=a150cb
#       → Crawling [4/10]: https://ashapuratoursandtravel.com/domain/akhwa.com
#       → Crawling [5/10]: https://ashapuratoursandtravel.com/contact
#       → Crawling [6/10]: https://ashapuratoursandtravel.com/domain/naklihane.com/backlink?hash=f4017b
#       → Crawling [7/10]: https://ashapuratoursandtravel.com/domain/kurapura.com/backlink?hash=505bdb
#       → Crawling [8/10]: https://ashapuratoursandtravel.com/domain/ashapuratoursandtravel.com
#       → Crawling [9/10]: https://ashapuratoursandtravel.com/domain/makipura.com/backlink?hash=d22ff8
#       → Crawling [10/10]: https://ashapuratoursandtravel.com/ashapuratravels19#
#   ✔ RESULT: False
#
# [STEP 63/677] Ashok Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://yahoo.co.in
#   ✔ RESULT: False
#
# [STEP 64/677] Asian Holiday
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://theasianholiday.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 65/677] Askanytime Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://askanytime.in, ranjeet.shrivastava
#     ❌ Error: HTTPSConnectionPool(host='askanytime.in,%20ranjeet.shrivastava', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='askanytime.in,%20ranjeet.shrivastava', port=443): Failed to resolve 'askanytime.in,%20ranjeet.shrivastava' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 66/677] Asmi Tours
#   📧 Email domain → search mode
#   🔍 Query: Asmi Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 67/677] Aspen Vacations
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://aspenvacations.co.in
#     ❌ Error: HTTPSConnectionPool(host='aspenvacations.co.in', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='aspenvacations.co.in', port=443): Failed to resolve 'aspenvacations.co.in' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 68/677] Aspire Square
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://holidaysquare.in
#   ✔ RESULT: True
#
# [STEP 69/677] Atlanta World Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://atlantaworldtravels.com
#   ✔ RESULT: False
#
# [STEP 70/677] AV BY SWETA
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://avbyswta.com
#     ❌ Error: HTTPSConnectionPool(host='avbyswta.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='avbyswta.com', port=443): Failed to resolve 'avbyswta.com' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 71/677] Avis Travels
#   📧 Email domain → search mode
#   🔍 Query: Avis Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 72/677] Aware Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Aware Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 73/677] Axis Travels
#   📧 Email domain → search mode
#   🔍 Query: Axis Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 74/677] Ayush Tours
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://ayushtours.com
#     ❌ Error: HTTPSConnectionPool(host='ayushtours.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'ayushtours.com'. (_ssl.c:1081)")))
#   ✔ RESULT: False
#
# [STEP 75/677] Ayushi Air Travels
#   📧 Email domain → search mode
#   🔍 Query: Ayushi Air Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 76/677] Balmer Lawrie & Co. Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://balmerlawrie.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://balmerlawrie.com/hi/company/financial-result
#       → Crawling [2/10]: https://balmerlawrie.com/storage/files/inoperative-ac-pf-31-03-2014.pdf
#       → Crawling [3/10]: https://balmerlawrie.com#main
#       → Crawling [4/10]: https://balmerlawrie.com/hi/sustainability/health-safety-and-environment
#       → Crawling [5/10]: https://balmerlawrie.com/storage/files/happy-foundation-day.jpeg
#       → Crawling [6/10]: https://balmerlawrie.com#
#       → Crawling [7/10]: https://balmerlawrie.com/storage/files/5074-balmer-lawrie-final.pdf
#       → Crawling [8/10]: https://balmerlawrie.com/storage/files/show-cause-notice-29-01-25.pdf
#       ✅ MICE FOUND on page!
#   ✔ RESULT: True
#
# [STEP 77/677] Believe Tours & Travels LLP
#   🌍 Website domain → crawler mode
#     ❌ Error: 'float' object has no attribute 'startswith'
#   ✔ RESULT: False
#
# [STEP 78/677] Best Tours & Forex Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://besttourstravels.com
#     ❌ Error: HTTPSConnectionPool(host='besttourstravels.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'besttourstravels.com'. (_ssl.c:1081)")))
#   ✔ RESULT: False
#
# [STEP 79/677] Best Voyage Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://bestvoyage.in, taufiq
#     ❌ Error: HTTPSConnectionPool(host='bestvoyage.in,%20taufiq', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='bestvoyage.in,%20taufiq', port=443): Failed to resolve 'bestvoyage.in,%20taufiq' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 80/677] Best World Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://rediffmail.com
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 81/677] Beyond Sunshine Holidays
#   📧 Email domain → search mode
#   🔍 Query: Beyond Sunshine Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 82/677] Bhagumama Holidays Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://bhagumamaholidays.in
#   ✔ RESULT: False
#
# [STEP 83/677] bhagwati aviations services pvt ltd
#   📧 Email domain → search mode
#   🔍 Query: bhagwati aviations services pvt ltd MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 84/677] Bhakti Travel Bureau
#   📧 Email domain → search mode
#   🔍 Query: Bhakti Travel Bureau MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 85/677] Bharat Darshan Travels
#   📧 Email domain → search mode
#   🔍 Query: Bharat Darshan Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 86/677] Bharat Tourism
#   📧 Email domain → search mode
#   🔍 Query: Bharat Tourism MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 87/677] Bhatiya Holidays
#   📧 Email domain → search mode
#   🔍 Query: Bhatiya Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 88/677] Bhavana Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Bhavana Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 89/677] Bhawna Holidays
#   📧 Email domain → search mode
#   🔍 Query: Bhawna Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 90/677] Bigsmile Holidays Pvt. Ltd.
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://bigsmileholidays.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://bigsmileholidays.com/blog/what-are-the-most-common-flight-booking-mistakes/
#       → Crawling [2/10]: https://bigsmileholidays.com/international-tours/vietnam/
#       → Crawling [3/10]: https://bigsmileholidays.com/tour/luxurious-escape-singapore-malaysia/
#       → Crawling [4/10]: https://bigsmileholidays.com/blogs/
#       → Crawling [5/10]: https://bigsmileholidays.com/assets/img/gallery/gallery_1_3.jpg
#       → Crawling [6/10]: https://bigsmileholidays.com/assets/img/gallery/gallery_1_7.jpg
#       → Crawling [7/10]: https://bigsmileholidays.com/assets/img/gallery/gallery_1_5.jpg
#       → Crawling [8/10]: https://bigsmileholidays.com/tour/southeast-singapore-malaysia-cruise-tour/
#       → Crawling [9/10]: https://bigsmileholidays.com/assets/img/gallery/gallery_1_2.jpg
#       → Crawling [10/10]: https://bigsmileholidays.com/blog/best-places-to-visit-in-europe/
#   ✔ RESULT: False
#
# [STEP 91/677] Bingo
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://bingo.travels
#     ❌ Error: HTTPSConnectionPool(host='bingo.travels', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='bingo.travels', port=443): Failed to resolve 'bingo.travels' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 92/677] Biz Link Tours
#   📧 Email domain → search mode
#   🔍 Query: Biz Link Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 93/677] BK Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: BK Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 94/677] Bleach Tourism
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://bleachtourism.com
#     🔗 Found 8 internal links
#       → Crawling [1/8]: https://bleachtourism.com/tours/luxurious-bali/
#       → Crawling [2/8]: https://bleachtourism.com#
#       → Crawling [3/8]: https://bleachtourism.com/
#       → Crawling [4/8]: https://bleachtourism.com/tours/classical-bali/
#       → Crawling [5/8]: https://bleachtourism.com/customer-feedback/
#       → Crawling [6/8]: https://bleachtourism.com#elementor-action%3Aaction%3Dpopup%3Aopen%26settings%3DeyJpZCI6IjM5NDMiLCJ0b2dnbGUiOmZhbHNlfQ%3D%3D
#       → Crawling [7/8]: https://bleachtourism.com/about-us/
#       → Crawling [8/8]: https://bleachtourism.com/form-view/1
#   ✔ RESULT: False
#
# [STEP 95/677] Bloom Overseas
#   📧 Email domain → search mode
#   🔍 Query: Bloom Overseas MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 96/677] Blu Tours & Camps
#   📧 Email domain → search mode
#   🔍 Query: Blu Tours & Camps MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 97/677] Blue Diamond Voyage N Vision Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://bluediamondvoyage.com
#     ❌ Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ✔ RESULT: False
#
# [STEP 98/677] Blue Escape Travel Solution
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://blueescape.in, info
#     ❌ Error: HTTPSConnectionPool(host='blueescape.in,%20info', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='blueescape.in,%20info', port=443): Failed to resolve 'blueescape.in,%20info' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 99/677] Blue Sky Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Blue Sky Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 100/677] Blue wings holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://bluewingsholidays.com
#   ✔ RESULT: False
#
# [STEP 101/677] Bounce Beyond Borders
#   📧 Email domain → search mode
#   🔍 Query: Bounce Beyond Borders MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 102/677] Boundless Trips/Oceania Trip
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://oceaniatrip.com
#   ✔ RESULT: False
#
# [STEP 103/677] Business Connection Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Business Connection Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 104/677] Butterflyers Holidays Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://butterflyers.biz
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 105/677] C R Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://crholidaysindia.com, info
#     ❌ Error: HTTPSConnectionPool(host='crholidaysindia.com,%20info', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='crholidaysindia.com,%20info', port=443): Failed to resolve 'crholidaysindia.com,%20info' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 106/677] C World Holidays
#   📧 Email domain → search mode
#   🔍 Query: C World Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 107/677] Capital Air Travels
#   📧 Email domain → search mode
#   🔍 Query: Capital Air Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 108/677] Care 4 Nature Holidays/C4N Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://c4nholidays.com
#     ❌ Error: HTTPSConnectionPool(host='c4nholidays.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<HTTPSConnection(host='c4nholidays.com', port=443) at 0x1deaae58e10>, 'Connection to c4nholidays.com timed out. (connect timeout=10)'))
#   ✔ RESULT: False
#
# [STEP 109/677] Carrera Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://carreraholidays.com
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 110/677] Chalo Holiday Travel consultant
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://chaloholidays.com
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 111/677] Chandan Travels
#   📧 Email domain → search mode
#   🔍 Query: Chandan Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 112/677] Chandramauli Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Chandramauli Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 113/677] Chhota Break Trip Planner
#   📧 Email domain → search mode
#   🔍 Query: Chhota Break Trip Planner MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 114/677] Chiky Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://chikytravels.com
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 115/677] Ciara World
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://ciaraworld.co.in
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://ciaraworld.co.in/uttarakhand-tour-packages
#       → Crawling [2/10]: https://ciaraworld.co.in/gallery
#       → Crawling [3/10]: https://ciaraworld.co.in/sri-lanka-tour-packages
#       → Crawling [4/10]: https://ciaraworld.co.in/7n-8d-himachal-pradesh-tour-package
#       → Crawling [5/10]: https://ciaraworld.co.in/international-tours
#       → Crawling [6/10]: https://ciaraworld.co.in/leh-ladakh-tour-packages
#       → Crawling [7/10]: https://ciaraworld.co.in/uttar-pradesh-tour-packages
#       → Crawling [8/10]: https://ciaraworld.co.in/abu-weekend-getaways-packages
#       → Crawling [9/10]: https://ciaraworld.co.in/5n-6d-gujarat-tour-package
#       → Crawling [10/10]: https://ciaraworld.co.in/privacy-policy
#   ✔ RESULT: False
#
# [STEP 116/677] Club 7 Holidays Ltd.
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://club7holidays.co.in
#     ❌ Error: HTTPSConnectionPool(host='club7holidays.co.in', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='club7holidays.co.in', port=443): Failed to resolve 'club7holidays.co.in' ([Errno 11002] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 117/677] columbus tourism
#   🌍 Website domain → crawler mode
#     ❌ Error: 'float' object has no attribute 'startswith'
#   ✔ RESULT: False
#
# [STEP 118/677] Comfort Zone
#   📧 Email domain → search mode
#   🔍 Query: Comfort Zone MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 119/677] Compass Holidays & Adventure - Trekking Tours & Travel Company
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://compassholidays.co.in
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://compassholidays.co.in
#       → Crawling [2/10]: https://compassholidays.co.in/tours/domestic.html
#       → Crawling [3/10]: https://compassholidays.co.in/privacy-policy-cookie-restriction-mode
#       → Crawling [4/10]: https://compassholidays.co.in/tours.html
#       → Crawling [5/10]: https://compassholidays.co.in/kasol-manali-trip.html
#       → Crawling [6/10]: https://compassholidays.co.in/treks/snow-treks.html/
#       → Crawling [7/10]: https://compassholidays.co.in/checkout/
#       → Crawling [8/10]: https://compassholidays.co.in/tours/upcoming-tours/upcoming-domestic-tours.html
#       → Crawling [9/10]: https://compassholidays.co.in/tours/upcoming-tours/upcoming-international-tours.html
#       → Crawling [10/10]: https://compassholidays.co.in#signup
#   ✔ RESULT: False
#
# [STEP 120/677] Compass Tourism
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://compasstourism.com
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 121/677] Corporate Traveller/FCM Travel Solutions pvt ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://in.fcm.travel
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://in.fcm.travel/en-in/corporate-travel-services/booker
#       → Crawling [2/10]: https://in.fcm.travel/en-in/technology/platform
#       → Crawling [3/10]: https://in.fcm.travel/en-in/discover-fcm/global-network
#       → Crawling [4/10]: https://in.fcm.travel/en-in/what-we-do/meetings-events
#       → Crawling [5/10]: https://in.fcm.travel/en-in/discover-fcm/news-hub
#       → Crawling [6/10]: https://in.fcm.travel/en-in/products/reporting-and-analytics
#       → Crawling [7/10]: https://in.fcm.travel/en-in/travel-insights/travel-hub
#       → Crawling [8/10]: https://in.fcm.travel/en-in/contact/enquiry
#       → Crawling [9/10]: https://in.fcm.travel/en-in/corporate-travel-services/traveller
#       → Crawling [10/10]: https://in.fcm.travel/en-in/discover-fcm/our-story
#   ✔ RESULT: False
#
# [STEP 122/677] Cosmic Travel
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://cosmictravel.co.in
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://cosmictravel.co.in#
#       → Crawling [2/10]: https://cosmictravel.co.in/tour/enchanting-new-zealand/
#       → Crawling [3/10]: https://cosmictravel.co.in/tour/spectacular-spain/
#       → Crawling [4/10]: https://cosmictravel.co.in/contacts-us/
#       → Crawling [5/10]: https://cosmictravel.co.in/ocean-odyssey/
#       → Crawling [6/10]: https://cosmictravel.co.in/tour-category/cosmic-tour/
#       → Crawling [7/10]: https://cosmictravel.co.in/tour/blissful-bali/
#       → Crawling [8/10]: https://cosmictravel.co.in/soulful-getaways/
#       → Crawling [9/10]: https://cosmictravel.co.in/about-us/
#       → Crawling [10/10]: https://cosmictravel.co.in/terms-conditions/
#   ✔ RESULT: False
#
# [STEP 123/677] Creative Tours & Travels (I) Pvt Ltd/FlyCreative online pvt ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://flycreative.in
#     🔗 Found 4 internal links
#       → Crawling [1/4]: https://flycreative.in/B2BWEB/Info/Contact
#       → Crawling [2/4]: https://flycreative.in/B2BWEB/Info/Home
#       → Crawling [3/4]: https://flycreative.in/B2BWEB/Info/About
#       → Crawling [4/4]: https://flycreative.in/B2BWEB/Info/Support
#   ✔ RESULT: False
#
# [STEP 124/677] Crosstrip cares
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://crosstripworld.in
#   ✔ RESULT: False
#
# [STEP 125/677] Crystal Tours & Travels Pvt Ltd
#   📧 Email domain → search mode
#   🔍 Query: Crystal Tours & Travels Pvt Ltd MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 126/677] Curated Travels By Smeet
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://curatedtravelsbysmeet.com
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 127/677] Dakshin Vacations Pvt. Ltd.
#   📧 Email domain → search mode
#   🔍 Query: Dakshin Vacations Pvt. Ltd. MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 128/677] Dattu Tours & Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://dattuholidays.in, info
#     ❌ Error: HTTPSConnectionPool(host='dattuholidays.in,%20info', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='dattuholidays.in,%20info', port=443): Failed to resolve 'dattuholidays.in,%20info' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 129/677] Dazzling Travel Planners
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://dazzlingtravelplanners.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://dazzlingtravelplanners.com/dubai-tour-operators-from-ahmedabad/
#       → Crawling [2/10]: https://dazzlingtravelplanners.com/visa-services/
#       → Crawling [3/10]: https://dazzlingtravelplanners.com/https:/dazzlingtravelplanners.com/tour-type/asia-and-far-east/
#     ❌ Error: cannot unpack non-iterable bool object
#   ✔ RESULT: False
#
# [STEP 130/677] De Getaways/Universal vacays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://universalvacays.com
#     ❌ Error: HTTPSConnectionPool(host='universalvacays.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'universalvacays.com'. (_ssl.c:1081)")))
#   ✔ RESULT: False
#
# [STEP 131/677] De La Vista Llp
#   📧 Email domain → search mode
#   🔍 Query: De La Vista Llp MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 132/677] Decent Deals Tourism
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://decentdealstourism.com
#     ❌ Error: HTTPSConnectionPool(host='decentdealstourism.com', port=443): Read timed out. (read timeout=10)
#   ✔ RESULT: False
#
# [STEP 133/677] Delmos World Pvt ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://delmosworld.com
#     ❌ Error: HTTPSConnectionPool(host='delmosworld.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='delmosworld.com', port=443): Failed to resolve 'delmosworld.com' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 134/677] Des Pardes Holidays
#   📧 Email domain → search mode
#   🔍 Query: Des Pardes Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 135/677] Desire Holidays
#   📧 Email domain → search mode
#   🔍 Query: Desire Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 136/677] Destination Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://destinations4india.com
#   ✔ RESULT: False
#
# [STEP 137/677] Destination Tourism
#   📧 Email domain → search mode
#   🔍 Query: Destination Tourism MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 138/677] Dh Holidays
#   📧 Email domain → search mode
#   🔍 Query: Dh Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 139/677] Dharnidhar Tours
#   📧 Email domain → search mode
#   🔍 Query: Dharnidhar Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 140/677] Dhidhi Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Dhidhi Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 141/677] Discover the World
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://discovertheworldindia.com
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 142/677] Discovery Tours - Luxury Holiday Tours
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://discoverytours.co.in
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://discoverytours.co.in/index.php/trip/golden-west-coast/
#       → Crawling [2/10]: https://discoverytours.co.in/index.php/trip/jordan-escape/
#       → Crawling [3/10]: https://discoverytours.co.in/index.php/activities/them-park/
#       → Crawling [4/10]: https://discoverytours.co.in/index.php/activities/rafting/
#       → Crawling [5/10]: https://discoverytours.co.in/index.php/trip-types/nature-walk/
#       → Crawling [6/10]: https://discoverytours.co.in/index.php/visa/
#       → Crawling [7/10]: https://discoverytours.co.in/index.php/destinations/europe/east-europe/
#       → Crawling [8/10]: https://discoverytours.co.in/index.php/tours/
#       → Crawling [9/10]: https://discoverytours.co.in/index.php/2024/09/16/login-get-25000-bonus-download-mostbet-app-126/
#       → Crawling [10/10]: https://discoverytours.co.in/index.php/trip/usa-east-coast/
#   ✔ RESULT: False
#
# [STEP 143/677] Disha Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://dishaholidays.com
#     ❌ Error: HTTPSConnectionPool(host='dishaholidays.com', port=443): Read timed out. (read timeout=10)
#   ✔ RESULT: False
#
# [STEP 144/677] DJ TRAVEL AGENCY
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://djtravelagency.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://djtravelagency.com#tab-2
#       → Crawling [2/10]: https://djtravelagency.com/privacy.html
#       → Crawling [3/10]: https://djtravelagency.com#tab-1
#       → Crawling [4/10]: https://djtravelagency.com/career.html
#       → Crawling [5/10]: https://djtravelagency.com/services.html
#       → Crawling [6/10]: https://djtravelagency.com/online-payment.html
#       → Crawling [7/10]: https://djtravelagency.com/terms.html
#       → Crawling [8/10]: https://djtravelagency.com/index.html
#       → Crawling [9/10]: https://djtravelagency.com/about.html
#       ✅ MICE FOUND on page!
#   ✔ RESULT: True
#
# [STEP 145/677] Dmc Tours & Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://dmctourstravels.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 146/677] Dream Casters
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://dreamcasters.in
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://dreamcasters.in/
#       → Crawling [2/10]: https://dreamcasters.in/services/
#       ✅ MICE FOUND on page!
#   ✔ RESULT: True
#
# [STEP 147/677] Dream Destinations Tours
#   📧 Email domain → search mode
#   🔍 Query: Dream Destinations Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 148/677] Dream Holidays
#   📧 Email domain → search mode
#   🔍 Query: Dream Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 149/677] Dream Vacanza
#   📧 Email domain → search mode
#   🔍 Query: Dream Vacanza MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 150/677] Dream Voyagers
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://dreamvoyagers.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 151/677] Dvoyagem
#   📧 Email domain → search mode
#   🔍 Query: Dvoyagem MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 152/677] D'Ziner Holidays /
# Dziner Travel Concepts
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://dzinerholidays.com, dzinerholidays
#     ❌ Error: HTTPSConnectionPool(host='dzinerholidays.com,%20dzinerholidays', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='dzinerholidays.com,%20dzinerholidays', port=443): Failed to resolve 'dzinerholidays.com,%20dzinerholidays' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 153/677] E Z Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://ezholidays.in,
#     ❌ Error: HTTPSConnectionPool(host='ezholidays.in,', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='ezholidays.in,', port=443): Failed to resolve 'ezholidays.in,' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 154/677] Earth Tour & Travels
#   📧 Email domain → search mode
#   🔍 Query: Earth Tour & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 155/677] Earth Trails
#   📧 Email domain → search mode
#   🔍 Query: Earth Trails MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 156/677] Easy Holiday
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://easyholiday.co.in
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://easyholiday.co.in/wp-login.php?action=login&redirect_to=https://easyholiday.co.in/
#       → Crawling [2/10]: https://easyholiday.co.in/2022/12/
#       → Crawling [3/10]: https://easyholiday.co.in/event/vancouver-international-travel-expo/
#     ❌ Error: cannot unpack non-iterable bool object
#   ✔ RESULT: False
#
# [STEP 157/677] Eco Tours And Travels
#   📧 Email domain → search mode
#   🔍 Query: Eco Tours And Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 158/677] Edu global star
#   📧 Email domain → search mode
#   🔍 Query: Edu global star MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 159/677] Electronika Travels & Tours
#   📧 Email domain → search mode
#   🔍 Query: Electronika Travels & Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 160/677] Enjoy The Journey/Columbus Tourism
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://columbustourism.net
#     🔗 Found 7 internal links
#       → Crawling [1/7]: https://columbustourism.net#our-services
#       → Crawling [2/7]: https://columbustourism.net#hero
#       → Crawling [3/7]: https://columbustourism.net/privacy-policy.html
#       → Crawling [4/7]: https://columbustourism.net#contact
#       → Crawling [5/7]: https://columbustourism.net#international
#       → Crawling [6/7]: https://columbustourism.net#about
#       → Crawling [7/7]: https://columbustourism.net#domestic
#   ✔ RESULT: False
#
# [STEP 161/677] Escape Holidays
#   📧 Email domain → search mode
#   🔍 Query: Escape Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 162/677] ESPI Tours & Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://espitravels.in, , sandip
#     ❌ Error: HTTPSConnectionPool(host='espitravels.in,%20,%20sandip', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='espitravels.in,%20,%20sandip', port=443): Failed to resolve 'espitravels.in,%20,%20sandip' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 163/677] European Holidays / A division of Akshar Tourism Pvt Ltd
#   📧 Email domain → search mode
#   🔍 Query: European Holidays / A division of Akshar Tourism Pvt Ltd MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 164/677] Exclusif Handcrafted Holidays pvt ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://exclusif.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 165/677] Exotic Days / Exotic Places Travel Services Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://exoticdays.org
#     ❌ Error: HTTPSConnectionPool(host='exoticdays.org', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<HTTPSConnection(host='exoticdays.org', port=443) at 0x1deb02fb610>, 'Connection to exoticdays.org timed out. (connect timeout=10)'))
#   ✔ RESULT: False
#
# [STEP 166/677] Exotic Holidays Hub
#   📧 Email domain → search mode
#   🔍 Query: Exotic Holidays Hub MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 167/677] Exotic Tourism
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://exotictourism.co.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 168/677] Exotic Tours
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://exoticholidayssurat.com
#     ❌ Error: HTTPSConnectionPool(host='exoticholidayssurat.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1081)')))
#   ✔ RESULT: False
#
# [STEP 169/677] Exotix Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://exoticholidays.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 170/677] Explore Travels
#   📧 Email domain → search mode
#   🔍 Query: Explore Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 171/677] Express Travels
#   📧 Email domain → search mode
#   🔍 Query: Express Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 172/677] FABULOUS HOLIDAYS
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://fabulousholidays.in
#   ✔ RESULT: False
#
# [STEP 173/677] Fairdeal Travels
#   📧 Email domain → search mode
#   🔍 Query: Fairdeal Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 174/677] Faro Duniya
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://faroduniya.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://faroduniya.com/tour-destination/south-africa/
#       → Crawling [2/10]: https://faroduniya.com/tour-destination/japan/
#       → Crawling [3/10]: https://faroduniya.com/tour-destination/rajasthan/
#       → Crawling [4/10]: https://faroduniya.com/tour-destination/russia/
#       → Crawling [5/10]: https://faroduniya.com/tour-destination/vietnam/
#       → Crawling [6/10]: https://faroduniya.com/register/
#       → Crawling [7/10]: https://faroduniya.com/tour-destination/australia/
#       → Crawling [8/10]: https://faroduniya.com/wp-content/uploads/2023/08/Capital-First.png
# ...
#     ❌ Error: HTTPSConnectionPool(host='venustours.co.in,%20vishal', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='venustours.co.in,%20vishal', port=443): Failed to resolve 'venustours.co.in,%20vishal' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 622/677] Venus Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Venus Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 623/677] Venus Travel And Tours
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://venustravelandtours.in
#   ✔ RESULT: False
#
# [STEP 624/677] Venus Travels
#   📧 Email domain → search mode
#   🔍 Query: Venus Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 625/677] Vibrant Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://vibrant-holidays.com
#     🔗 Found 8 internal links
#       → Crawling [1/8]: https://vibrant-holidays.com#tab2
#       → Crawling [2/8]: https://vibrant-holidays.com#tab4
#       → Crawling [3/8]: https://vibrant-holidays.com#tab5
#       → Crawling [4/8]: https://vibrant-holidays.com#tab7
#       → Crawling [5/8]: https://vibrant-holidays.com#tab6
#       → Crawling [6/8]: https://vibrant-holidays.com#tab3
#       → Crawling [7/8]: https://vibrant-holidays.com#tab1
#       → Crawling [8/8]: https://vibrant-holidays.com#
#   ✔ RESULT: False
#
# [STEP 626/677] Vir Holidays
#   📧 Email domain → search mode
#   🔍 Query: Vir Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 627/677] Visa 2 Travel
#   📧 Email domain → search mode
#   🔍 Query: Visa 2 Travel MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 628/677] Visamo The Eco World
#   📧 Email domain → search mode
#   🔍 Query: Visamo The Eco World MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 629/677] Vishal Travels Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://vishaltravels.in, rina
#     ❌ Error: HTTPSConnectionPool(host='vishaltravels.in,%20rina', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='vishaltravels.in,%20rina', port=443): Failed to resolve 'vishaltravels.in,%20rina' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 630/677] Vishw Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://vishwholidays.com
#     ❌ Error: HTTPSConnectionPool(host='vishwholidays.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='vishwholidays.com', port=443): Failed to resolve 'vishwholidays.com' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 631/677] Vishwa Travels
#   📧 Email domain → search mode
#   🔍 Query: Vishwa Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 632/677] Vishwa World Travelplum Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://travelplum.io
#     🔗 Found 7 internal links
#       → Crawling [1/7]: https://travelplum.io/mlink/?branchseo=rikvip-z&affid=657a9ee06d5783d37e258fed8942de7c
#       → Crawling [2/7]: https://travelplum.io#top
#       → Crawling [3/7]: https://travelplum.io#
#       → Crawling [4/7]: https://travelplum.io/cdn-cgi/l/email-protection
#     ❌ Error: cannot unpack non-iterable bool object
#   ✔ RESULT: False
#
# [STEP 633/677] Vithalani Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://vithalaniholidays.com
#     ❌ Error: HTTPSConnectionPool(host='vithalaniholidays.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='vithalaniholidays.com', port=443): Failed to resolve 'vithalaniholidays.com' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 634/677] Viva Holidays
#   📧 Email domain → search mode
#   🔍 Query: Viva Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 635/677] vogue tourism llp
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://voguetourism.com
#     🔗 Found 6 internal links
#       → Crawling [1/6]: https://voguetourism.com/forgot-password
#       → Crawling [2/6]: https://voguetourism.com/terms-of-use
#       → Crawling [3/6]: https://voguetourism.com#
#       → Crawling [4/6]: https://voguetourism.com/login
#       → Crawling [5/6]: https://voguetourism.com
#       → Crawling [6/6]: https://voguetourism.com#tab1holidays
#   ✔ RESULT: False
#
# [STEP 636/677] Voiceholidays
#   📧 Email domain → search mode
#   🔍 Query: Voiceholidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 637/677] Voyage Leisure Tours
#   📧 Email domain → search mode
#   🔍 Query: Voyage Leisure Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 638/677] Voyage Vision
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://voyagevision.co.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 639/677] Vraj - The Tour Planet
#   📧 Email domain → search mode
#   🔍 Query: Vraj - The Tour Planet MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 640/677] Vrinda Destinations -escape explore experience
#   📧 Email domain → search mode
#   🔍 Query: Vrinda Destinations -escape explore experience MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 641/677] Vyas Travels Pvt Ltd
#   📧 Email domain → search mode
#   🔍 Query: Vyas Travels Pvt Ltd MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 642/677] Vyom Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://vyomholidays.com
#     🔗 Found 1 internal links
#       → Crawling [1/1]: https://vyomholidays.com/index.html
#   ✔ RESULT: False
#
# [STEP 643/677] Walk about Group
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://walkaboutgroup.in
#     ❌ Error: HTTPSConnectionPool(host='walkaboutgroup.in', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='walkaboutgroup.in', port=443): Failed to resolve 'walkaboutgroup.in' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 644/677] Walker Tourism
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://walkertourism.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://walkertourism.com/trip/best-of-kerala/
#       → Crawling [2/10]: https://walkertourism.com/trip/wildlife-tour/
#       → Crawling [3/10]: https://walkertourism.com/trip/exotic-himachal/
#       → Crawling [4/10]: https://walkertourism.com/trip/exotic-himachal-with-chandigarh/
#       → Crawling [5/10]: https://walkertourism.com/destinations/south-africa/
#       → Crawling [6/10]: https://walkertourism.com/trip/picturesque-singapore/
#       → Crawling [7/10]: https://walkertourism.com/trip/mesmerised-kerala/
#       → Crawling [8/10]: https://walkertourism.com/destinations/uttarakhand/
#       → Crawling [9/10]: https://walkertourism.com/trip/dubai-with-atlantis/
#       → Crawling [10/10]: https://walkertourism.com/destinations/france/
#   ✔ RESULT: False
#
# [STEP 645/677] Wanderers Leisure Travels Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://thewanderers.co.in
#   ✔ RESULT: False
#
# [STEP 646/677] Wanderlust Tours And Travel
#   📧 Email domain → search mode
#   🔍 Query: Wanderlust Tours And Travel MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 647/677] White Swan Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://whiteswanholidays.com
#   ✔ RESULT: True
#
# [STEP 648/677] White swan Holidays
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://whiteswanholidays.com
#   ✔ RESULT: True
#
# [STEP 649/677] Wide World Services
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://wideworldservices.in , ops
#     ❌ Error: HTTPSConnectionPool(host='wideworldservices.in%20,%20ops', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='wideworldservices.in%20,%20ops', port=443): Failed to resolve 'wideworldservices.in%20,%20ops' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 650/677] Windex Tours & Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://windextours.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 651/677] World Trade Tour & Travels
#   📧 Email domain → search mode
#   🔍 Query: World Trade Tour & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 652/677] World Travel & Tourism
#   📧 Email domain → search mode
#   🔍 Query: World Travel & Tourism MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 653/677] World Travels (I) Ltd
#   📧 Email domain → search mode
#   🔍 Query: World Travels (I) Ltd MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 654/677] World Vision Tours & Travels (India)
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://yahoo.co.in
#   ✔ RESULT: False
#
# [STEP 655/677] World Wide Travels
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://worldwidetravels.in
#   ✔ RESULT: False
#
# [STEP 656/677] Worldwide Overseas Travel Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://overseastravel.co.in
#     🔗 Found 0 internal links
#   ✔ RESULT: False
#
# [STEP 657/677] Xceed travels
#   📧 Email domain → search mode
#   🔍 Query: Xceed travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 658/677] Y and s holiday
#   📧 Email domain → search mode
#   🔍 Query: Y and s holiday MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 659/677] Yan Travel World(YTW)
#   📧 Email domain → search mode
#   🔍 Query: Yan Travel World(YTW) MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 660/677] Yanu Holidays & Hospitality
#   📧 Email domain → search mode
#   🔍 Query: Yanu Holidays & Hospitality MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 661/677] Yash Airways
#   📧 Email domain → search mode
#   🔍 Query: Yash Airways MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 662/677] Yatra Online Pvt Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://yatra.com, kushboo.pandya
#     ❌ Error: HTTPSConnectionPool(host='yatra.com,%20kushboo.pandya', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='yatra.com,%20kushboo.pandya', port=443): Failed to resolve 'yatra.com,%20kushboo.pandya' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 663/677] Yesh Travel International
#   📧 Email domain → search mode
#   🔍 Query: Yesh Travel International MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 664/677] Yogi Holidays
#   📧 Email domain → search mode
#   🔍 Query: Yogi Holidays MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 665/677] Yrp Tours And Travels
#   📧 Email domain → search mode
#   🔍 Query: Yrp Tours And Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 666/677] Zephyrs Tours
#   📧 Email domain → search mode
#   🔍 Query: Zephyrs Tours MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 667/677] Zydus Travel N Ease Pvt. Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://travelnease.com
#     ❌ Error: HTTPSConnectionPool(host='travelnease.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'travelnease.com'. (_ssl.c:1081)")))
#   ✔ RESULT: False
#
# [STEP 668/677] nan
#   🌍 Website domain → crawler mode
#     ❌ Error: 'float' object has no attribute 'startswith'
#   ✔ RESULT: False
#
# [STEP 669/677] JIIPS Travel Partner (JTP)
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://jiipstravelpartner.com
#     🔗 Found 3 internal links
#       → Crawling [1/3]: https://jiipstravelpartner.com?MA
#       → Crawling [2/3]: https://jiipstravelpartner.com?ND
#       → Crawling [3/3]: https://jiipstravelpartner.com?SA
#   ✔ RESULT: False
#
# [STEP 670/677] Globe All india Services
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://globeindia.in
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://globeindia.in/wp-content/uploads/2023/05/22.png
#       → Crawling [2/10]: https://globeindia.in/wp-content/uploads/2023/05/26.png
#       → Crawling [3/10]: https://globeindia.in/wp-content/uploads/2023/05/18.png
#       → Crawling [4/10]: https://globeindia.in/?pt=room&type=booking&tourmaster-payment
#       → Crawling [5/10]: https://globeindia.in/wp-content/uploads/2023/05/1.png
#       → Crawling [6/10]: https://globeindia.in/2026/03/27/
#       → Crawling [7/10]: https://globeindia.in/wp-content/uploads/2023/05/9.png
#       → Crawling [8/10]: https://globeindia.in/wp-content/uploads/2023/05/10.png
#       → Crawling [9/10]: https://globeindia.in#
#       → Crawling [10/10]: https://globeindia.in/wp-content/uploads/2023/05/20.png
#   ✔ RESULT: False
#
# [STEP 671/677] Zenith Leisure Holidays Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://zenithholidays.co.in
#     ❌ Error: HTTPSConnectionPool(host='zenithholidays.co.in', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("HTTPSConnection(host='zenithholidays.co.in', port=443): Failed to resolve 'zenithholidays.co.in' ([Errno 11001] getaddrinfo failed)"))
#   ✔ RESULT: False
#
# [STEP 672/677] Travel World
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://taai.in
#     ❌ Error: HTTPSConnectionPool(host='taai.in', port=443): Max retries exceeded with url: / (Caused by NewConnectionError("HTTPSConnection(host='taai.in', port=443): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it"))
#   ✔ RESULT: False
#
# [STEP 673/677] Bleach Tourism Pvt. Ltd.
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://bleachtourism.com
#     🔗 Found 8 internal links
#       → Crawling [1/8]: https://bleachtourism.com/tours/luxurious-bali/
#       → Crawling [2/8]: https://bleachtourism.com#
#       → Crawling [3/8]: https://bleachtourism.com/
#       → Crawling [4/8]: https://bleachtourism.com/tours/classical-bali/
#       → Crawling [5/8]: https://bleachtourism.com/customer-feedback/
#       → Crawling [6/8]: https://bleachtourism.com#elementor-action%3Aaction%3Dpopup%3Aopen%26settings%3DeyJpZCI6IjM5NDMiLCJ0b2dnbGUiOmZhbHNlfQ%3D%3D
#       → Crawling [7/8]: https://bleachtourism.com/about-us/
#       → Crawling [8/8]: https://bleachtourism.com/form-view/1
#   ✔ RESULT: False
#
# [STEP 674/677] Sanskar Travels
#   📧 Email domain → search mode
#   🔍 Query: Sanskar Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 675/677] Zoom Travelling Pvt. Ltd.
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://zoomtravelling.co.in
#     🔗 Found 5 internal links
#       → Crawling [1/5]: https://zoomtravelling.co.in/services/
#       → Crawling [2/5]: https://zoomtravelling.co.in#
#       → Crawling [3/5]: https://zoomtravelling.co.in/contact-us/
#       → Crawling [4/5]: https://zoomtravelling.co.in/
#       → Crawling [5/5]: https://zoomtravelling.co.in/about-us/
#   ✔ RESULT: False
#
# [STEP 676/677] Royal Tours & Travels
#   📧 Email domain → search mode
#   🔍 Query: Royal Tours & Travels MICE meetings incentives conferences exhibitions
#   ✔ RESULT: False
#
# [STEP 677/677] Stelle Tours & Forex Pvt. Ltd
#   🌍 Website domain → crawler mode
#     🌐 Opening: https://stelletours.com
#     🔗 Found 10 internal links
#       → Crawling [1/10]: https://stelletours.com/Domestic-tours.php
#       → Crawling [2/10]: https://stelletours.com/Package_Bangkok_Pattaya.php
#       → Crawling [3/10]: https://stelletours.com/About.php
#       → Crawling [4/10]: https://stelletours.com#mobile-menu-01
#       → Crawling [5/10]: https://stelletours.com/index.php
#       → Crawling [6/10]: https://stelletours.com/Passport.php
#       → Crawling [7/10]: https://stelletours.com/Gallery.php
#       → Crawling [8/10]: https://stelletours.com/Contact.php
#       → Crawling [9/10]: https://stelletours.com#
#       → Crawling [10/10]: https://stelletours.com/Package_Dubai.php
#   ✔ RESULT: False
#
# DONE ✔ Saved file
